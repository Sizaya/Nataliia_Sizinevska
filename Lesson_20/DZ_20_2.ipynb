# %%
from random_words import RandomWords

str_list = []

w = RandomWords()

for i in range(0, 5000):
    str_list.append(w.random_word())
    
print('Str list: ', str_list)

def bubble_sort(data):
    length = len(data)
    for iIndex in range(length):
        swapped = False
        for jIndex in range(0, length - iIndex - 1):
            if data[jIndex] > data[jIndex + 1]:
                data[jIndex], data[jIndex + 1] = data[jIndex + 1], data[jIndex]
                swapped = True
        if not swapped:
            break
# Out:
# Str list:  ['sill', 'catchers', 'relations', 'armory', 'spokes', 'stretches', 'mates', 'atmospheres', 'confusion', 'drillers', 'detachment', 'accountability', 'moneys', 'trusts', 'package', 'rank', 'meters', 'platforms', 'hull', 'aim', 'clips', 'ammonia', 'roof', 'anchors', 'sponsors', 'fabrication', 'seeds', 'waterlines', 'apprehension', 'misalignment', 'combatants', 'ramp', 'carloads', 'mates', 'loaf', 'millimeters', 'conjunction', 'troubleshooters', 'tissues', 'selection', 'car', 'beaches', 'vine', 'appraisals', 'publications', 'hours', 'shower', 'builder', 'hangars', 'typewriter', 'vents', 'spirals', 'crust', 'remainder', 'relief', 'disassembly', 'number', 'adhesive', 'navies', 'recording', 'messenger', 'saturdays', 'corps', 'parity', 'tool', 'burn', 'rags', 'manual', 'overtime', 'arrangements', 'posts', 'axis', 'throttle', 'trap', 'enemies', 'shout', 'transiting', 'uses', 'appearance', 'compartment', 'overcurrent', 'glove', 'steeples', 'gardens', 'rigs', 'steeples', 'nameplates', 'liberties', 'waterline', 'billet', 'round', 'quartermaster', 'outlines', 'detection', 'forests', 'paw', 'peace', 'passage', 'allotments', 'reenlistment', 'clock', 'prisons', 'finger', 'terrain', 'auto', 'ponds', 'vent', 'competition', 'hatch', 'fracture', 'trays', 'additives', 'decoders', 'torpedoes', 'merchant', 'bandages', 'transits', 'countries', 'january', 'shares', 'focus', 'plants', 'intake', 'preventions', 'factors', 'rush', 'rowers', 'woman', 'semiconductor', 'enclosures', 'kiloliter', 'fashions', 'gloves', 'taxes', 'bottle', 'friday', 'resource', 'deaths', 'bridge', 'bristles', 'proficiency', 'specialization', 'gums', 'daughter', 'pool', 'nerve', 'clap', 'berries', 'directives', 'cloud', 'mask', 'handles', 'verse', 'magnitude', 'grid', 'surplus', 'origin', 'histories', 'verb', 'fantails', 'hall', 'cages', 'semiconductors', 'codes', 'expense', 'initials', 'quart', 'dockings', 'armful', 'fracture', 'strobes', 'feathers', 'airships', 'socks', 'residents', 'remainders', 'affairs', 'millimeter', 'bundles', 'baths', 'stretches', 'authority', 'contents', 'deviation', 'staples', 'alias', 'vibrations', 'connection', 'earth', 'threats', 'classroom', 'groove', 'verses', 'appropriation', 'compliance', 'cots', 'leaper', 'thousand', 'dependence', 'ear', 'advisers', 'looks', 'programs', 'shot', 'pine', 'radiation', 'electrodes', 'boiler', 'blueprints', 'collars', 'wafers', 'sediments', 'heading', 'motion', 'cashier', 'baskets', 'modification', 'rotor', 'face', 'pokes', 'advantage', 'bomb', 'lime', 'payroll', 'accord', 'requirement', 'hello', 'crops', 'allocations', 'results', 'officers', 'cruise', 'cheeses', 'jumper', 'milestones', 'chiefs', 'jumper', 'bushing', 'bread', 'abrasives', 'absences', 'compromise', 'cloudiness', 'wingnut', 'august', 'election', 'fantail', 'custom', 'profits', 'liberty', 'method', 'gangs', 'patterns', 'secrets', 'handler', 'moisture', 'designation', 'snow', 'porters', 'coxswains', 'initials', 'cups', 'swings', 'servants', 'offenses', 'showers', 'curl', 'ribs', 'inaction', 'tents', 'stomach', 'pistons', 'bunch', 'space', 'minds', 'leak', 'relief', 'coals', 'reconfigurations', 'builders', 'generators', 'pavement', 'suns', 'breath', 'symptoms', 'auditors', 'horns', 'dew', 'economies', 'requisitions', 'want', 'lungs', 'guard', 'hit', 'arc', 'sign', 'pedal', 'observations', 'gum', 'spear', 'terminology', 'paths', 'electron', 'spades', 'filler', 'geography', 'spots', 'professionalism', 'traps', 'branches', 'cavities', 'layers', 'salute', 'kick', 'miner', 'cuffs', 'watches', 'howl', 'concepts', 'stator', 'documentation', 'briefings', 'bed', 'lengths', 'direction', 'deeds', 'monolith', 'rower', 'recombinations', 'doors', 'guilt', 'submarining', 'transport', 'instrument', 'road', 'seams', 'capacities', 'juries', 'bypasses', 'kills', 'communication', 'henrys', 'requirement', 'insanity', 'annexs', 'bin', 'overcurrent', 'contracts', 'reading', 'invoices', 'ticket', 'accordance', 'misalignments', 'variation', 'ores', 'samples', 'shelter' ...

# %%
# %%timeit -n 1 -r 5
import time
time.sleep(1)
# Out:
# 1 s ± 36.1 µs per loop (mean ± std. dev. of 5 runs, 1 loop each)

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Створення випадкових даних
X = np.linspace(0, 10, 100)  # Генеруємо 100 рівномірно розподілених значень від 0 до 10
y = 2 * X + 3 + np.random.normal(0, 1, 100)  # Генеруємо відповіді, які лінійно залежать від x з доданим шумом

# %%
# Розбиття даних на тренувальну та тестову вибірки
X_train, X_test = x[:80], x[80:]
y_train, y_test = y[:80], y[80:]

# %%
# Побудова моделі лінійної регресії
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=(1,))
])

# %%
# Компіляція моделі
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# Навчання моделі
history = model.fit(X_train, y_train, epochs=100, verbose=0)

# %%
# Передбачення для тестової вибірки
y_pred = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 43ms/step

# %%
# Виведення графіка результатів
plt.scatter(X_test, y_test, label='Дані')
plt.plot(X_test, y_pred, color='red', label='Лінійна регресія')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
